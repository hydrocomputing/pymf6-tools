# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
from pathlib import Path

# %%
from pymf6tools.make_model import run_simulation

# %%
from pymf6tools.plotting import show_heads, show_well_head, show_concentration, show_bcs

# %%
from pymf6tools.base_model import BASE_MODEL_DATA

# %%
model_path = Path('models/transport_river_base').absolute()
model_name = 'transriver'

# %%
run_simulation(model_path)

# %%
show_bcs?
# Out:
# Signature:
# show_bcs(
#     model_path,
#     name,
#     title='Boundary Conditions',
#     bc_names=('chd', 'wel', 'riv'),
#     show_grid=True,
# )
# Docstring: Show location of boundary conditions.
# File:      ~/Dev/pymf6tools/src/pymf6tools/plotting.py
# Type:      function

# %%
show_bcs(model_path, model_name, bc_names=('chd', 'riv-1', 'wel'))

# %%
show_heads(model_path, model_name, show_wells=False)

# %%
show_well_head?
# Out:
# Signature:
# show_well_head(
#     wel_coords,
#     model_path,
#     model_name,
#     times,
#     title='',
#     y_start=0.3,
#     y_end=1.05,
#     upper_head_limit=None,
#     lower_head_limit=None,
#     x=(0, 32),
# )
# Docstring: Plot head at well over time.
# File:      ~/Dev/pymf6tools/src/pymf6tools/plotting.py
# Type:      function

# %%
show_well_head((0, 4, 4), model_path, model_name, BASE_MODEL_DATA['times'], y_start=0, y_end=20)
